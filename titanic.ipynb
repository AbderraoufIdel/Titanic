# %%
from plotnine import * 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
import os 
for dirname, _, filenames in os.walk(r"C:\Users\abder\Desktop\folder0\Titanic"):
   for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\abder\Desktop\folder0\Titanic\gender_submission.csv
# C:\Users\abder\Desktop\folder0\Titanic\README.md
# C:\Users\abder\Desktop\folder0\Titanic\submission.csv
# C:\Users\abder\Desktop\folder0\Titanic\test.csv
# C:\Users\abder\Desktop\folder0\Titanic\titanic.ipynb
# C:\Users\abder\Desktop\folder0\Titanic\Titanic.py
# C:\Users\abder\Desktop\folder0\Titanic\train.csv
# C:\Users\abder\Desktop\folder0\Titanic\.git\COMMIT_EDITMSG
# C:\Users\abder\Desktop\folder0\Titanic\.git\config
# C:\Users\abder\Desktop\folder0\Titanic\.git\description
# C:\Users\abder\Desktop\folder0\Titanic\.git\HEAD
# C:\Users\abder\Desktop\folder0\Titanic\.git\index
# C:\Users\abder\Desktop\folder0\Titanic\.git\packed-refs
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\applypatch-msg.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\commit-msg.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\fsmonitor-watchman.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\post-update.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\pre-applypatch.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\pre-commit.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\pre-merge-commit.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\pre-push.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\pre-rebase.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\pre-receive.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\prepare-commit-msg.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\push-to-checkout.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\sendemail-validate.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\hooks\update.sample
# C:\Users\abder\Desktop\folder0\Titanic\.git\info\exclude
# C:\Users\abder\Desktop\folder0\Titanic\.git\logs\HEAD
# C:\Users\abder\Desktop\folder0\Titanic\.git\logs\refs\heads\main
# C:\Users\abder\Desktop\folder0\Titanic\.git\logs\refs\remotes\origin\HEAD
# C:\Users\abder\Desktop\folder0\Titanic\.git\logs\refs\remotes\origin\main
# C:\Users\abder\Desktop\folder0\Titanic\.git\objects\2e\4ed6b51ae5c9c90506df99345f19a6b7359487
# C:\Users\abder\Desktop\folder0\Titanic\.git\objects\85\5835375a712bc6e700cc7b5c969619e926e239
# C:\Users\abder\Desktop\folder0\Titanic\.git\objects\dc\a2d3e4e1b71ef040e17b3e5374ef2fdde378ad
# C:\Users\abder\Desktop\folder0\Titanic\.git\objects\pack\pack-de056f39a97451835d98c1bd90155084d4b2fe95.idx
# C:\Users\abder\Desktop\folder0\Titanic\.git\objects\pack\pack-de056f39a97451835d98c1bd90155084d4b2fe95.pack
# C:\Users\abder\Desktop\folder0\Titanic\.git\objects\pack\pack-de056f39a97451835d98c1bd90155084d4b2fe95.rev
# C:\Users\abder\Desktop\folder0\Titanic\.git\refs\heads\main
# C:\Users\abder\Desktop\folder0\Titanic\.git\refs\remotes\origin\HEAD
# C:\Users\abder\Desktop\folder0\Titanic\.git\refs\remotes\origin\main

# %%
'''let's create a function, feed the training and test data sets as an input, 
and at the output we will get a combined one, without an index'''
def concat_df(train_data, test_data):
    # Returns a concatenated df of training and test set
    return pd.concat([train_data, test_data], sort=True).reset_index(drop=True)

'''Let's create a function at the input of which we feed the combined data set, 
and at the output it returns the separated df of the training and test set, saved without a label'''
def divide_df(all_data):
    # Returns divided dfs of training and test set
    return all_data.loc[:890], all_data.loc[891:].drop(['Survived'], axis=1)



'''The Python Pandas packages helps us work with our datasets. 
We start by acquiring the training and testing datasets into Pandas DataFrames. 
We also combine these datasets to run certain operations on both datasets together.
'''
df_train = pd.read_csv(r'C:\Users\abder\Desktop\folder0\Titanic\train.csv')  # load train data
df_test = pd.read_csv(r'C:\Users\abder\Desktop\folder0\Titanic\test.csv')  # load test data
df_all = concat_df(df_train, df_test)  # we apply the function described above, the union of two dataframes.

'''supplement the data sets with the name parameter'''
df_train.name = 'Training Set'  # set parameter for dataset - dataframe name
df_test.name = 'Test Set'  # set parameter for dataset - dataframe name
df_all.name = 'All Set'  # set parameter for dataset - dataframe name 

dfs = [df_train, df_test]

# display information about datasets
print('Number of Training Examples = {}'.format(df_train.shape[0]))
print('Number of Test Examples = {}\n'.format(df_test.shape[0]))
print('Training X Shape = {}'.format(df_train.shape))
print('Training y Shape = {}\n'.format(df_train['Survived'].shape[0]))
print('Test X Shape = {}'.format(df_test.shape))
print('Test y Shape = {}\n'.format(df_test.shape[0]))
print(df_train.columns)
print(df_test.columns)
print(df_train.info())
print(df_train.describe())
df_train.sample(5)
# Out:
# Number of Training Examples = 891
# Number of Test Examples = 418
#
# Training X Shape = (891, 12)
# Training y Shape = 891
#
# Test X Shape = (418, 11)
# Test y Shape = 418
#
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 578          579         0       3  Caram, Mrs. Joseph (Maria Elias)  female
# 598          599         0       3                 Boulos, Mr. Hanna    male
# 6              7         0       1           McCarthy, Mr. Timothy J    male
# 365          366         0       3    Adahl, Mr. Mauritz Nils Martin    male
# 555          556         0       1                Wright, Mr. George    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 578   NaN      1      0    2689  14.4583   NaN        C
# 598   NaN      0      0    2664   7.2250   NaN        C
# 6    54.0      0      0   17463  51.8625   E46        S
# 365  30.0      0      0  C 7076   7.2500   NaN        S
# 555  62.0      0      0  113807  26.5500   NaN        S

# %%
numeric_df = df_train.select_dtypes(include=['number'])

# Plot the heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
fig = plt.gcf()
fig.set_size_inches(10, 8)
plt.show()

# %%
def display_missing(df):    
    for col in df.columns.tolist():          
        print('{} column missing values: {}'.format(col, df[col].isnull().sum()))
    print('\n')
    
for df in dfs:
    print('{}'.format(df.name))
    display_missing(df)
# Out:
# Training Set
# PassengerId column missing values: 0
# Survived column missing values: 0
# Pclass column missing values: 0
# Name column missing values: 0
# Sex column missing values: 0
# Age column missing values: 177
# SibSp column missing values: 0
# Parch column missing values: 0
# Ticket column missing values: 0
# Fare column missing values: 0
# Cabin column missing values: 687
# Embarked column missing values: 2
#
#
# Test Set
# PassengerId column missing values: 0
# Pclass column missing values: 0
# Name column missing values: 0
# Sex column missing values: 0
# Age column missing values: 86
# SibSp column missing values: 0
# Parch column missing values: 0
# Ticket column missing values: 0
# Fare column missing values: 1
# Cabin column missing values: 327
# Embarked column missing values: 0

# %%
df_train[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
df_train['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
(ggplot(df_train)
 + aes(x='Sex', y='Survived')
 + geom_col()
 + ggtitle('gender survival rate')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
(ggplot(df_train)
 + aes(x='Sex', y='Survived', fill='Embarked')
 + geom_col()
)

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df_train['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# Although it is a number, it is changed to a string because it is categorical data
df_train['Pclass'] = df_train['Pclass'].astype('str')

pd.crosstab(df_train.Pclass,df_train.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_339a1_row0_col0, #T_339a1_row1_col1, #T_339a1_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_339a1_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_339a1_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_339a1_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_339a1_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_339a1_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_339a1_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_339a1_row3_col0, #T_339a1_row3_col1, #T_339a1_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_339a1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_339a1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_339a1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_339a1_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_339a1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_339a1_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_339a1_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_339a1_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_339a1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_339a1_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_339a1_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_339a1_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_339a1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_339a1_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_339a1_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_339a1_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_339a1_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_339a1_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_339a1_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_339a1_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
(ggplot(df_train)
 + aes(x='Sex', y='Survived', fill='Pclass')
 + geom_col()
)

# %%
df_train['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df_train[["Age", "Survived"]].groupby(['Age'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Age  Survived
# 0    0.42       1.0
# 1    0.67       1.0
# 2    0.75       1.0
# 3    0.83       1.0
# 4    0.92       1.0
# ..    ...       ...
# 81  65.00       0.0
# 83  70.00       0.0
# 84  70.50       0.0
# 85  71.00       0.0
# 86  74.00       0.0
#
# [88 rows x 2 columns]

# %%
train_dropna_age = df_train['Age'].dropna()

# %%
(ggplot(df_train)
 + aes(x='Age', y='Fare')
 + geom_point()
 + ggtitle('Fares by age group')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
df_train['Survived'] = df_train['Survived'].astype('category')

# %%
(ggplot(df_train)
 + aes(x='Age', y='Fare', color='Survived')
 + geom_point()
 + stat_smooth()
 + ggtitle('Age group and fare survival rate')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
# Is there a correlation between age and Pclass?
(ggplot(df_train)
 + aes(x='Age', y='Fare', color='Pclass')
 + geom_point()
 + stat_smooth()
)

# %%
(ggplot(df_train) 
 + aes(x='Age', y='Fare', color='Sex')
 + geom_point()
 + stat_smooth()
 + facet_wrap('~Survived')
)

# %%
df_train['Survived'] = df_train['Survived'].astype('category')

# %%
# See the correlation between age and fare gender
(ggplot(df_train) 
 + aes(x='Age', y='Fare', color='Survived')
 + geom_point()
 + stat_smooth()
 + facet_wrap('~Pclass')
 + ggtitle('age rate grade survival rate')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
(ggplot(df_train)
 + aes(x='Age', y='Fare', fill='Pclass')
 + geom_point()
 + ggtitle('Gender rate distribution by survival')
 + facet_wrap('~Survived')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
(ggplot(df_train)
 + aes(x='Age', y='Fare', fill='Pclass')
 + geom_point()
 + stat_smooth()
 + ggtitle('Gender fare class distribution')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
# View correlation between age and fare gender
(ggplot(df_train) 
 + aes(x='Sex', y='Age')
 + geom_boxplot()
 + ggtitle('Gender Age Boxplot')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
(ggplot(df_train) 
 + aes(x='Sex', y='Fare', fill='Survived')
 + geom_boxplot()
 + ggtitle('Sex Fare Survival Rate')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
(ggplot(df_train) 
 + aes(x='Survived', y='Age', fill='Pclass')
 + geom_boxplot()
 + ggtitle('Gender Age Rating')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
(ggplot(df_train) 
 + aes(x='Age')
 + geom_histogram(binwidth=10)
 + ggtitle('age distribution')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.

# %%
df_all['Age'] = pd.qcut(df_all['Age'], 10)
fig, axs = plt.subplots(figsize=(22, 9))
sns.countplot(x='Age', hue='Survived', data=df_all)

plt.xlabel('Age', size=15, labelpad=20)
plt.ylabel('Passenger Count', size=15, labelpad=20)
plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)

plt.legend(['Not Survived', 'Survived'], loc='upper right', prop={'size': 15})
plt.title('Survival Counts in {} Feature'.format('Age'), size=15, y=1.05)

plt.show()

# %%
print('Oldest Passenger was of:',df_train['Age'].max(),'Years')
print('Youngest Passenger was of:',df_train['Age'].min(),'Years')
print('Average Age on the ship:',df_train['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
df_train['Initial']=0
for i in df_train:
    df_train['Initial']=df_train.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
    
'''We are using the Regex: [A-Za-z]+).. 
So what it does is, it looks for strings which lie between A-Z or a-z and followed by a .(dot). 
So we successfully extract the Initials from the Name.'''

pd.crosstab(df_train.Initial,df_train.Sex).T.style.background_gradient(cmap='summer_r')  # Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_19a04_row0_col0, #T_19a04_row0_col1, #T_19a04_row0_col3, #T_19a04_row0_col4, #T_19a04_row0_col5, #T_19a04_row0_col7, #T_19a04_row0_col8, #T_19a04_row0_col12, #T_19a04_row0_col15, #T_19a04_row0_col16, #T_19a04_row1_col2, #T_19a04_row1_col6, #T_19a04_row1_col9, #T_19a04_row1_col10, #T_19a04_row1_col11, #T_19a04_row1_col13, #T_19a04_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_19a04_row0_col2, #T_19a04_row0_col6, #T_19a04_row0_col9, #T_19a04_row0_col10, #T_19a04_row0_col11, #T_19a04_row0_col13, #T_19a04_row0_col14, #T_19a04_row1_col0, #T_19a04_row1_col1, #T_19a04_row1_col3, #T_19a04_row1_col4, #T_19a04_row1_col5, #T_19a04_row1_col7, #T_19a04_row1_col8, #T_19a04_row1_col12, #T_19a04_row1_col15, #T_19a04_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19a04">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_19a04_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_19a04_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_19a04_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_19a04_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_19a04_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_19a04_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_19a04_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_19a04_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_19a04_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_19a04_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_19a04_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_19a04_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_19a04_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_19a04_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_19a04_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_19a04_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_19a04_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19a04_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_19a04_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_19a04_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_19a04_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_19a04_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_19a04_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_19a04_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_19a04_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_19a04_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_19a04_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_19a04_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_19a04_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_19a04_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_19a04_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_19a04_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_19a04_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_19a04_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_19a04_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_19a04_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_19a04_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_19a04_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_19a04_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_19a04_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_19a04_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_19a04_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_19a04_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_19a04_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_19a04_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_19a04_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_19a04_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_19a04_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_19a04_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_19a04_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_19a04_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_19a04_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_19a04_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
df_train.groupby('Initial')['Age'].mean()  # lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
# Assigning the NaN Values with the Ceil values of the mean ages
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'),'Age']=33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'),'Age']=36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'),'Age']=5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'),'Age']=22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'),'Age']=46
df_train.Age.isnull().any()  # So no null values left finally
# Out:
# np.False_

# %%
print("Train Cabin missing: " + str(df_train.Cabin.isnull().sum()/len(df_train.Cabin)))
print("Test Cabin missing: " + str(df_test.Cabin.isnull().sum()/len(df_test.Cabin)))
# Out:
# Train Cabin missing: 0.7710437710437711
# Test Cabin missing: 0.7822966507177034

# %%
# print(df_all.info())
# Assign all the null values to N
df_all.Cabin.fillna("N", inplace=True)

# group these cabins according to the letter of the cabin name
df_all.Cabin = [str(i)[0] for i in df_all.Cabin]



def percent_value_counts(df, feature):
    """This function takes in a dataframe and a column and finds the percentage of the value_counts"""
    percent = pd.DataFrame(round(df.loc[:,feature].value_counts(dropna=False, normalize=True)*100,2))
    ## creating a df with th
    total = pd.DataFrame(df.loc[:,feature].value_counts(dropna=False))
    ## concating percent and total dataframe

    total.columns = ["Total"]
    percent.columns = ['Percent']
    return pd.concat([total, percent], axis = 1)

percent_value_counts(df_all, "Cabin")
# Out:
#        Total  Percent
# Cabin
# N       1014    77.46
# C         94     7.18
# B         65     4.97
# D         46     3.51
# E         41     3.13
# A         22     1.68
# F         21     1.60
# G          5     0.38
# T          1     0.08

# %%
df_all.groupby("Cabin")['Fare'].mean().sort_values()
# Out:
# Cabin
# G     14.205000
# F     18.079367
# N     19.132707
# T     35.500000
# A     41.244314
# D     53.007339
# E     54.564634
# C    107.926598
# B    122.383078
# Name: Fare, dtype: float64

# %%
def cabin_estimator(i):
    """Grouping cabin feature by the first letter"""
    a = 0
    if i<16:
        a = "G"
    elif i>=16 and i<27:
        a = "F"
    elif i>=27 and i<38:
        a = "T"
    elif i>=38 and i<47:
        a = "A"
    elif i>= 47 and i<53:
        a = "E"
    elif i>= 53 and i<54:
        a = "D"
    elif i>=54 and i<116:
        a = 'C'
    else:
        a = "B"
    return a

'''Now, these means can help us determine the unknown cabins, if we compare each unknown cabin rows with the given mean's above. 
Let's write a simple function so that we can give cabin names based on the means.'''

#applying cabin estimator function. 
df_all['Cabin'] = df_all.Fare.apply(lambda x: cabin_estimator(x))

percent_value_counts(df_all, "Cabin")
# Out:
#        Total  Percent
# Cabin
# G        714    54.55
# F        201    15.36
# C        143    10.92
# T        109     8.33
# B         72     5.50
# A         37     2.83
# E         27     2.06
# D          6     0.46

# %%
# Creating Deck column from the first letter of the Cabin column (M stands for Missing)
df_all['Deck'] = df_all['Cabin'].apply(lambda s: s[0] if pd.notnull(s) else 'M')

df_all_decks = df_all.groupby(['Deck', 'Pclass']).count().drop(columns=['Survived', 'Sex', 'Age', 'SibSp', 'Parch', 
                                                                        'Fare', 'Embarked', 'Cabin', 'PassengerId', 'Ticket']).rename(columns={'Name': 'Count'}).transpose()

def get_pclass_dist(df):
    
    # Creating a dictionary for every passenger class count in every deck
    deck_counts = {'A': {}, 'B': {}, 'C': {}, 'D': {}, 'E': {}, 'F': {}, 'G': {}, 'M': {}, 'T': {}}
    decks = df.columns.levels[0]    
    
    for deck in decks:
        for pclass in range(1, 4):
            try:
                count = df[deck][pclass][0]
                deck_counts[deck][pclass] = count 
            except KeyError:
                deck_counts[deck][pclass] = 0
                
    df_decks = pd.DataFrame(deck_counts)    
    deck_percentages = {}

    # Creating a dictionary for every passenger class percentage in every deck
    for col in df_decks.columns:
        deck_percentages[col] = [(count / df_decks[col].sum()) * 100 for count in df_decks[col]]
        
    return deck_counts, deck_percentages

def display_pclass_dist(percentages):
    
    df_percentages = pd.DataFrame(percentages).transpose()
    deck_names = ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'M', 'T')
    bar_count = np.arange(len(deck_names))  
    bar_width = 0.85
    
    pclass1 = df_percentages[0]
    pclass2 = df_percentages[1]
    pclass3 = df_percentages[2]
    
    plt.figure(figsize=(20, 10))
    plt.bar(bar_count, pclass1, color='#b5ffb9', edgecolor='white', width=bar_width, label='Passenger Class 1')
    plt.bar(bar_count, pclass2, bottom=pclass1, color='#f9bc86', edgecolor='white', width=bar_width, label='Passenger Class 2')
    plt.bar(bar_count, pclass3, bottom=pclass1 + pclass2, color='#a3acff', edgecolor='white', width=bar_width, label='Passenger Class 3')

    plt.xlabel('Deck', size=15, labelpad=20)
    plt.ylabel('Passenger Class Percentage', size=15, labelpad=20)
    plt.xticks(bar_count, deck_names)    
    plt.tick_params(axis='x', labelsize=15)
    plt.tick_params(axis='y', labelsize=15)
    
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), prop={'size': 15})
    plt.title('Passenger Class Distribution in Decks', size=18, y=1.05)   
    
    plt.show()    

all_deck_count, all_deck_per = get_pclass_dist(df_all_decks)
display_pclass_dist(all_deck_per)

# %%
# Passenger in the T deck is changed to A
idx = df_all[df_all['Deck'] == 'T'].index
df_all.loc[idx, 'Deck'] = 'A'

df_all_decks_survived = df_all.groupby(['Deck', 'Survived']).count().drop(columns=['Sex', 'Age', 'SibSp', 'Parch', 'Fare', 
                                                                                   'Embarked', 'Pclass', 'Cabin', 'PassengerId', 'Ticket']).rename(columns={'Name':'Count'}).transpose()

def get_survived_dist(df):
    
    # Creating a dictionary for every survival count in every deck
    surv_counts = {'A':{}, 'B':{}, 'C':{}, 'D':{}, 'E':{}, 'F':{}, 'G':{}, 'M':{}}
    decks = df.columns.levels[0]    

    for deck in decks:
        for survive in range(0, 2):
            surv_counts[deck][survive] = df[deck][survive][0]
            
    df_surv = pd.DataFrame(surv_counts)
    surv_percentages = {}

    for col in df_surv.columns:
        surv_percentages[col] = [(count / df_surv[col].sum()) * 100 for count in df_surv[col]]
        
    return surv_counts, surv_percentages

def display_surv_dist(percentages):
    
    df_survived_percentages = pd.DataFrame(percentages).transpose()
    deck_names = ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'M')
    bar_count = np.arange(len(deck_names))  
    bar_width = 0.85    

    not_survived = df_survived_percentages[0]
    survived = df_survived_percentages[1]
    
    plt.figure(figsize=(20, 10))
    plt.bar(bar_count, not_survived, color='#b5ffb9', edgecolor='white', width=bar_width, label="Not Survived")
    plt.bar(bar_count, survived, bottom=not_survived, color='#f9bc86', edgecolor='white', width=bar_width, label="Survived")
 
    plt.xlabel('Deck', size=15, labelpad=20)
    plt.ylabel('Survival Percentage', size=15, labelpad=20)
    plt.xticks(bar_count, deck_names)    
    plt.tick_params(axis='x', labelsize=15)
    plt.tick_params(axis='y', labelsize=15)
    
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), prop={'size': 15})
    plt.title('Survival Percentage in Decks', size=18, y=1.05)
    
    plt.show()

all_surv_count, all_surv_per = get_survived_dist(df_all_decks_survived)
display_surv_dist(all_surv_per)

# %%
df_all['Fare'] = pd.qcut(df_all['Fare'], 13)
fig, axs = plt.subplots(figsize=(22, 9))
sns.countplot(x='Fare', hue='Survived', data=df_all)

plt.xlabel('Fare', size=15, labelpad=20)
plt.ylabel('Passenger Count', size=15, labelpad=20)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=15)

plt.legend(['Not Survived', 'Survived'], loc='upper right', prop={'size': 15})
plt.title('Count of Survival in {} Feature'.format('Fare'), size=15, y=1.05)

plt.show()

# %%
df_train['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_train[df_train.Embarked.isnull()]
# Out:
#      PassengerId Survived Pclass                                       Name  \
# 61            62        1      1                        Icard, Miss. Amelie
# 829          830        1      1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Initial
# 61   female  38.0      0      0  113572  80.0   B28      NaN    Miss
# 829  female  62.0      0      0  113572  80.0   B28      NaN     Mrs

# %%
df_train['Survived'] = pd.to_numeric(df_train['Survived'], errors='coerce')

# %%
df_train['Embarked'] = df_train['Embarked'].astype('category')

# %%
df_train['Embarked'].fillna('C', inplace = True)
df_train['Embarked'].value_counts()

df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean()
# Out:
#   Embarked  Survived
# 0        C  0.558824
# 1        Q  0.389610
# 2        S  0.336957

# %%
pd.crosstab([df_train.Embarked,df_train.Pclass],[df_train.Sex,df_train.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_ce7bf_row0_col0, #T_ce7bf_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_ce7bf_row0_col1 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_ce7bf_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_ce7bf_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_ce7bf_row0_col4 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_ce7bf_row1_col0, #T_ce7bf_row3_col0, #T_ce7bf_row3_col1, #T_ce7bf_row3_col2, #T_ce7bf_row3_col3, #T_ce7bf_row3_col4, #T_ce7bf_row4_col0, #T_ce7bf_row4_col2, #T_ce7bf_row4_col3, #T_ce7bf_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ce7bf_row1_col1, #T_ce7bf_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_ce7bf_row1_col3, #T_ce7bf_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_ce7bf_row2_col0, #T_ce7bf_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_ce7bf_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_ce7bf_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_ce7bf_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_ce7bf_row2_col4, #T_ce7bf_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_ce7bf_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_ce7bf_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_ce7bf_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_ce7bf_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_ce7bf_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_ce7bf_row6_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_ce7bf_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_ce7bf_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_ce7bf_row6_col4, #T_ce7bf_row7_col3, #T_ce7bf_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_ce7bf_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_ce7bf_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_ce7bf_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_ce7bf_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_ce7bf_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_ce7bf_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_ce7bf_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_ce7bf_row9_col0, #T_ce7bf_row9_col1, #T_ce7bf_row9_col2, #T_ce7bf_row9_col3, #T_ce7bf_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce7bf">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_ce7bf_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_ce7bf_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_ce7bf_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_ce7bf_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_ce7bf_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_ce7bf_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_ce7bf_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_ce7bf_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce7bf_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_ce7bf_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_ce7bf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ce7bf_row0_col1" class="data row0 col1" >44</td>
#       <td id="T_ce7bf_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_ce7bf_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_ce7bf_row0_col4" class="data row0 col4" >87</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_ce7bf_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_ce7bf_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_ce7bf_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_ce7bf_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_ce7bf_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_ce7bf_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_ce7bf_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_ce7bf_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_ce7bf_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_ce7bf_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_ce7bf_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_ce7bf_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_ce7bf_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_ce7bf_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_ce7bf_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_ce7bf_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_ce7bf_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_ce7bf_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_ce7bf_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_ce7bf_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_ce7bf_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_ce7bf_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_ce7bf_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_ce7bf_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_ce7bf_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_ce7bf_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_ce7bf_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_ce7bf_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_ce7bf_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_ce7bf_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_ce7bf_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_ce7bf_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_ce7bf_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_ce7bf_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_ce7bf_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_ce7bf_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_ce7bf_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_ce7bf_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_ce7bf_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_ce7bf_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_ce7bf_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_ce7bf_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_ce7bf_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_ce7bf_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_ce7bf_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# Pie chart for 'Survived' column
df_all['Survived'].value_counts().plot.pie(
    explode=[0, 0.1], 
    autopct='%1.1f%%', 
    ax=ax[0], 
    shadow=True
)
ax[0].set_title('Survived')
ax[0].set_ylabel('')

# Count plot for 'Survived' column
sns.countplot(x='Survived', data=df_all, ax=ax[1])
ax[1].set_title('Survived')

# Show the plot
plt.show()

# %%
submission = pd.read_csv(r'C:\Users\abder\Desktop\folder0\Titanic\submission.csv')
submission.to_csv('submission.csv', index=False)
